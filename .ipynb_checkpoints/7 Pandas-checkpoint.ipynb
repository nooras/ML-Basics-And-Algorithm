# %% [markdown]
# # Pandas

# %%
# Data Visualization tools

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range( '2020-02-01' , periods = 1000),columns = ['value']) #Multi Dimensional data frame
ts = pd.Series(randn(1000), index = pd.date_range( '2020-02-01' , periods = 1000))

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2020-02-01 -0.154001
# 2020-02-02 -0.610030
# 2020-02-03 -1.329677
# 2020-02-04 -2.475236
# 2020-02-05 -3.428881

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2020-02-01    0.716445
# 2020-02-02    1.076873
# 2020-02-03    2.002947
# 2020-02-04    1.251531
# 2020-02-05    0.478397
# Freq: D, dtype: float64

# %%
type(df) , type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %% [markdown]
# # Line plot

# %%
ts.plot()

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()

# %%
ax = iris.plot(figsize=(15,8), title='Iris dataset')
ax.set_xlabel("X axis")
ax.set_xlabel("Y axis")
# Out:
# Text(0.5,0,'Y axis')

# %% [markdown]
# # Bar plot

# %%
ts.plot(kind='bar')

# %%
ts.plot(kind='hist')

# %%
df.iloc[0].plot('bar')

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
abc = iris.drop(['species'], axis=1)

# %%
abc.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
abc.iloc[0].plot(kind='bar')

# %%
abc.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='bar')

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  2.485000 -1.540657  0.178308  1.065458
# 1  1.240299 -0.380917  0.235382  0.885325
# 2  1.306804  0.790538  0.171987  0.801589
# 3  0.208434 -0.329344 -0.374859  1.978440
# 4 -1.936357 -0.012710  1.255497  2.829206

# %%
df.plot.bar()

# %%
df
# Out:
#           a         b         c         d
# 0  2.485000 -1.540657  0.178308  1.065458
# 1  1.240299 -0.380917  0.235382  0.885325
# 2  1.306804  0.790538  0.171987  0.801589
# 3  0.208434 -0.329344 -0.374859  1.978440
# 4 -1.936357 -0.012710  1.255497  2.829206
# 5 -0.160094 -0.876372  0.366565 -1.639297
# 6  0.618120 -0.305646  0.256077 -0.428844
# 7  1.049727 -1.489177  0.147237  0.303549
# 8 -0.257062  1.672693  0.005445  0.539597
# 9  1.522743 -0.731287  0.181660  1.109343

# %%
df.plot.hist()

# %%
titanic['pclass'].plot.hist()

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh(stacked=True)  #Horizontal bar plot

# %% [markdown]
# # Histogram

# %%
iris.plot.hist()

# %%
iris.plot(kind='hist')

# %%
iris.plot( kind='hist' , stacked=True , bins=20 )

# %%
iris.plot( kind='hist' , stacked=True , bins=50 )

# %%
iris.plot( kind='hist' , stacked=True , bins=20 , orientation='horizontal' )

# %%
iris['sepal_length'].diff().plot( kind='hist' , stacked=True , bins=50 )  #Difference plot

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = iris.drop(['species'], axis=1)

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d5921c0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d591985c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d59140c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d59171320>]],
#       dtype=object)

# %%
df.diff().hist(color='r' , alpha=0.5 , figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d593e1c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d590002b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d59026940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d58fd0fd0>]],
#       dtype=object)

# %% [markdown]
# # Box Plot

# %%
# For finding max and min value

# %%
color = {'boxes':'DarkGreen', 'whiskers':'r'}
df.plot(kind='box',color=color)

# %%
df.plot(kind='box',color=color , vert=False)

# %% [markdown]
# # Area Plot

# %%
df.plot(kind='area')

# %%
df.plot.area(stacked=False)

# %% [markdown]
# # Scatter plot

# %%
df.plot.scatter(x='sepal_length', y='petal_length')

# %%
df.plot.scatter(x='sepal_length', y='petal_length' , c='sepal_width')

# %%
ax = df.plot.scatter(x='sepal_length', y='petal_length' , label='length')
df.plot.scatter(x='sepal_width', y='petal_width' , label='width' , ax=ax , color='r')

# %%
df.plot.scatter(x='sepal_length', y='petal_length' , c='sepal_width' , s=df['petal_width']*200)

# %% [markdown]
# # Hexagonal bin plot

# %%
df.plot.hexbin(x='sepal_length' , y='petal_length' , gridsize=10 , C='sepal_width')

# %% [markdown]
# # Pie plot

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10) )

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(20,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d55316f60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d552ce6a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d552f7c18>],
#       dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,5) , fontsize=16 ,autopct='%.2f' )
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d552085f8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d55235860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d551dedd8>],
#       dtype=object)

# %%
series = pd.Series([0.1]*4 , index=['a','b','c','d'])
series.plot.pie()

# %%
series = pd.Series([0.2]*4 , index=['a','b','c','d'] , name='Pie Plot')
series.plot.pie()

# %% [markdown]
# # Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(8,8))
plt.show()

# %%
scatter_matrix(df , figsize=(8,8) , diagonal='kde' , color='r')
plt.show()
