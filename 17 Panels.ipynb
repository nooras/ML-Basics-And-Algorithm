# %%
import pandas as pd
from pandas_datareader import data

# %%
company = ['MSFT', 'GOOG', 'AAPL', 'YHOO', 'AMZN']
p = data.DataReader(name=company, data_source='yahoo', start='2010-01-01', end='2016-12-31')
# Out:
# /home/ansari/anaconda3/lib/python3.6/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'YHOO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
p
# Out:
# Attributes   Adj Close                                               Close  \
# Symbols           AAPL        AMZN        GOOG       MSFT YHOO        AAPL
# Date
# 2009-12-31   26.131752  134.520004  308.832428  23.925440  NaN   30.104286
# 2010-01-04   26.538483  133.899994  312.204773  24.294369  NaN   30.572857
# 2010-01-05   26.584366  134.690002  310.829926  24.302216  NaN   30.625713
# 2010-01-06   26.161509  132.250000  302.994293  24.153070  NaN   30.138571
# 2010-01-07   26.113146  130.000000  295.940735  23.901886  NaN   30.082857
# 2010-01-08   26.286753  133.520004  299.885956  24.066734  NaN   30.282858
# 2010-01-11   26.054865  130.309998  299.432648  23.760603  NaN   30.015715
# 2010-01-12   25.758488  127.349998  294.137512  23.603607  NaN   29.674286
# 2010-01-13   26.121826  129.110001  292.448822  23.823395  NaN   30.092857
# 2010-01-14   25.970547  127.349998  293.823669  24.302216  NaN   29.918571
# ...

# %%
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
p.ndim
# Out:
# 2

# %%
p['Volume']
# Out:
# Symbols            AAPL        AMZN        GOOG         MSFT  YHOO
# Date
# 2009-12-31   88102700.0   4523000.0   2448700.0   31929700.0   NaN
# 2010-01-04  123432400.0   7599900.0   3927000.0   38409100.0   NaN
# 2010-01-05  150476200.0   8851900.0   6031900.0   49749600.0   NaN
# 2010-01-06  138040000.0   7178800.0   7987100.0   58182400.0   NaN
# 2010-01-07  119282800.0  11030200.0  12876600.0   50559700.0   NaN
# 2010-01-08  111902700.0   9830500.0   9483900.0   51197400.0   NaN
# 2010-01-11  115557400.0   8779400.0  14479800.0   68754700.0   NaN
# 2010-01-12  148614900.0   9096300.0   9742900.0   65912100.0   NaN
# 2010-01-13  151473000.0  10723200.0  13041800.0   51863500.0   NaN
# 2010-01-14  108223500.0   9774900.0   8511900.0   63228100.0   NaN
# 2010-01-15  148516900.0  15376500.0  10909600.0   79913200.0   NaN
# 2010-01-19  182501900.0   8892600.0   8665700.0   46575700.0   NaN
# 2010-01-20  153038200.0   9074700.0   6525700.0   54849500.0   NaN
# ...

# %%
p.items
# Out:
# <bound method DataFrame.iteritems of Attributes   Adj Close                                               Close  \
# Symbols           AAPL        AMZN        GOOG       MSFT YHOO        AAPL
# Date
# 2009-12-31   26.131752  134.520004  308.832428  23.925440  NaN   30.104286
# 2010-01-04   26.538483  133.899994  312.204773  24.294369  NaN   30.572857
# 2010-01-05   26.584366  134.690002  310.829926  24.302216  NaN   30.625713
# 2010-01-06   26.161509  132.250000  302.994293  24.153070  NaN   30.138571
# 2010-01-07   26.113146  130.000000  295.940735  23.901886  NaN   30.082857
# 2010-01-08   26.286753  133.520004  299.885956  24.066734  NaN   30.282858
# 2010-01-11   26.054865  130.309998  299.432648  23.760603  NaN   30.015715
# 2010-01-12   25.758488  127.349998  294.137512  23.603607  NaN   29.674286
# 2010-01-13   26.121826  129.110001  292.448822  23.823395  NaN   30.092857
# 2010-01-14   25.970547  127.349998  293.823669  24.302216  NaN   29.918571
# ...

# %%
p.major_xs('2016-09-06')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-db7309742c41> in <module>()
# ----> 1 p.major_xs('2016-09-06')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'major_xs'
